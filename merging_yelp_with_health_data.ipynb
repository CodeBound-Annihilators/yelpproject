# %%
import pandas as pd

# %%
yelp_df = pd.read_csv('comma_separted_values/prepped_yelp_data.csv')

# %%
health_df = pd.read_csv('comma_separted_values/prepped_health_data.csv')

# %%
yelp_df[yelp_df.address.isnull()]
# Out:
#       Unnamed: 0   display_phone       distance                      id  \
# 72            72  (214) 282-3932    8327.147345  T5EIOlmzWAxnHXmBFd8T9Q
# 76            76             NaN    8073.416704  UYS35udDfDUvZTkfA3eXZQ
# 82            82  (210) 800-1525    8073.416704  9QL55WA1sMGY0j1CpS2dug
# 283          283  (210) 984-4499    4345.588434  kthLZuVtn6WFRBQBAxo_bg
# 317          317  (808) 554-1471   29115.989575  cX31TWJDbeMqMK4SY84GnA
# 321          321  (956) 241-1364   50469.472579  5_YSW-gQ-TDZsRTOwOhUUA
# 410          410  (956) 792-9066   50469.472579  5IQisCGCi5w4CupJrTtRWw
# 415          415  (210) 502-7961   11639.174692  miMCO7ZtGtQ7gF5m--MJog
# 416          416  (210) 201-3008    9984.483225  fN6xsWY8eqzRTHfrMKPkrQ
# 419          419  (210) 723-7417   11964.852431  dR0odVSRujgfB_EUkRT-Fw
# 421          421  (210) 249-6252   16031.580506  7Kvp0n8Dfcg8o0CsE93Phg
# 422          422  (210) 387-6461   28507.441949  hnTUy0VovHAn18SwZYs5Mw
# ...

# %%
dropped_na = yelp_df.address.dropna()

# %%
len(dropped_na)
# Out:
# 6380

# %%
# merged_df = pd.merge(yelp_df, health_df, right_on='address')

# %%
health_df.shape
# Out:
# (42053, 9)

# %%
health_df.address.nunique()
# Out:
# 6677

# %%
yelp_df.shape
# Out:
# (6553, 15)

# %%
yelp_df.address.nunique()
# Out:
# 3245
