# %%
import pandas as pd
import numpy as np

# %%
columns = ['address', 'district', 'complete_address', 'inspection_date', 'inspector', 'link', 'sector', 'total_score', 'violations']

# %%
inspectors = pd.read_csv('health_inspection.csv')

# %%
inspectors = inspectors.drop(columns='Unnamed: 0')

# %%
inspectors
# Out:
#                            Address DISTRICT  \
# 0                6909  N FM 1604 E        B
# 1               5506  SAN PEDRO AV        B
# 2                   502  RIVERWALK        C
# 3                 8224  FREDSBG RD        A
# 4                   3710  BROADWAY        B
# 5              20210  STONE OAK PY        B
# 6                     1700  CLOWER        A
# 7              5115  THOUSAND OAKS        B
# 8                 1134  CULEBRA RD        D
# 9                  1621  MAIN AV N        D
# 10              1539  PALO ALTO RD        D
# 11                    505  FAIR AV        C
# 12                 13700  US 281 N        B
# 13                2296  BANDERA RD        A
# 14           18803  HARDY OAK BLVD        B
# 15                  4130  BROADWAY        B
# 16               2482  LOOP 410 NE        B
# 17                  526  RIVERWALK        C
# 18                 2101  EDISON DR        A
# 19                 1421  CLOWER ST        A
# ...
