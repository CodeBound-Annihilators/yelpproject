# %%
##business search

URL = 'https://www.yelp.com/developers/documentation/v3/business_search'

# %%
import requests
import get_my_key
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %%
#Client ID
Client_ID = '8686c761d3182d6d8499bf7ef711556921f22a2b'

# %%
api_key = get_my_key.api_key()
endpoint = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization' : 'Bearer %s' % api_key}

# %%
parameters = {'limit': 50,
    'location': 'San Antonio'}

# %%
response = requests.get(url = endpoint, params = parameters, headers = headers)

# %%
business_data = response.json()

# %%
business_data['total']
# Out:
# 3200

# %%
parameters = {'limit': 50,
              'offset': 50,
              'categories': 'bars',
    'location': 'San Antonio'}

response = requests.get(url = endpoint, params = parameters, headers = headers)
business_data1 = response.json()
business_data1['total']
# business_data1['businesses']
# busines_dert = pd.read_json(business_data1)
# busines_dert
# Out:
# 470

# %%
test = json_normalize(business_data1['businesses'])
# Out:
# alias                       50
# categories                  50
# coordinates.latitude        50
# coordinates.longitude       50
# display_phone               50
# distance                    50
# id                          50
# image_url                   50
# is_closed                   50
# location.address1           50
# location.address2           41
# location.address3           48
# location.city               50
# location.country            50
# location.display_address    50
# location.state              50
# location.zip_code           50
# name                        50
# phone                       50
# price                       50
# rating                      50
# review_count                50
# transactions                50
# url                         50
# dtype: int64

# %%
    
    offset = 0
    parameters = {'limit': 50,
                  'offset': 50,
                  'radius': 40000,
        'location': 'San Antonio'}


    
for o in offset:
    parameters = {'limit': 50,
                  'offset': o,
                  'radius': 40000,
        'location': 'San Antonio'}
    response = requests.get(url = endpoint, params = parameters, headers = headers)
    business_data1 = response.json()
    offset = offset + 50

# %%
def search_restaurants(set_num): 
# This function launches the request for all restaurants in San Antonio, Tx.
    category = []
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': 'Bearer %s'% api_key,
    }
    url_params = { #parameters passed to the API
    "location":"San Antonio",
    "state": "Texas",
    "category": category,
    'offset': offset_num, # We are going to iterate the offset
     "limit":50 # Maximum return of results per request (ref: API documentation).
     }

    response = requests.get(url, headers=headers, params=url_params)
    return response.json() # Returns a JSON.


if __name__ == "__main__":
    for offset_num in np.arange(0,1000,50) : 
# Desire 3200 results, in steps of 50 results per request.
        try:
            output_json = search_restaurants(offset_num) # Executing the function defined above.
            print(offset_num) # Making sure each offset iteration is running
            print(output_json) # If you wanna check the JSON for each iteration
            if offset_num == 50:
                df_first = pd.DataFrame.from_dict(output_json['businesses'])
# 'businesses' because that's the primary key of the JSON (i.e. pull all attribute data by calling 
# that one key). This is something you can figure out reading the API documentation or visually
# parsing the JSON. 
            else:
                df_first = pd.DataFrame.from_dict(output_json['businesses'])
                df2 = pd.DataFrame.from_dict(output_json['businesses'])
                df_first = df_first.append(df2)
# The conditional statement above is so that I can append my results into a single dataframe, to 
# save into a single csv document.
        except AttributeError:
            print("error at ", offset_num) # Helpful for debugging purposes
            
    df_first.to_csv("output_data1.csv", index = False)
# Out:
# 0
# {'businesses': [{'id': 'K444c79c_uHQ4at6rCxk5Q', 'alias': 'ginos-deli-stop-n-buy-san-antonio', 'name': "Gino's Deli Stop N Buy", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZTmo7WiScVYKem9s-pYtfg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/ginos-deli-stop-n-buy-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 1033, 'categories': [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 5.0, 'coordinates': {'latitude': 29.56441, 'longitude': -98.55768}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '13210 Huebner Rd', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78230', 'country': 'US', 'state': 'TX', 'display_address': ['13210 Huebner Rd', 'San Antonio, TX 78230']}, 'phone': '+12107640602', 'display_phone': '(210) 764-0602', 'distance': 8834.283454738568}, {'id': 'AsL7ifh6n0r9eGkhij6-Ng', 'alias': 'the-esquire-tavern-san-antonio', 'name': 'The Esquire Tavern', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tIrzyaUuXJmHwIfbnY3PVw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-esquire-tavern-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 2507, 'categories': [{'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}], 'rating': 4.0, 'coordinates': {'latitude': 29.4247334154792, 'longitude': -98.4917683754631}, 'transactions': ['restaurant_reservation', 'pickup'], 'price': '$$', 'location': {'address1': '155 E Commerce St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78205', 'country': 'US', 'state': 'TX', 'display_address': ['155 E Commerce St', 'San Antonio, TX 78205']}, 'phone': '+12102222521', 'display_phone': '(210) 222-2521', 'distance': 8054.697723522756}, {'id': 'A-2-cH0dGVDY7tEs_0BTEA', 'alias': 'boudros-on-the-river-walk-san-antonio', 'name': "Boudro's On the River Walk", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Gw6pKiflUdZQwvRqDx_9vg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/boudros-on-the-river-walk-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 2359, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 4.0, 'coordinates': {'latitude': 29.42412, 'longitude': -98.48839}, 'transactions': ['delivery'], 'price': '$$$', 'location': {'address1': '421 E Commerce St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78205', 'country': 'US', 'state': 'TX', 'display_address': ['421 E Commerce St', 'San Antonio, TX 78205']}, 'phone': '+12102248484', 'display_phone': '(210) 224-8484', 'distance': 8220.553657627619}, {'id': '_S3cq-DYrsSIpv3EI45ErA', 'alias': 'the-magnolia-pancake-haus-san-antonio', 'name': 'The Magnolia Pancake Haus', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eD-DRmcHHdpR2FP3ac_L5A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-magnolia-pancake-haus-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 1884, 'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newamerican', 'title': 'American (New)'}], 'rating': 4.0, 'coordinates': {'latitude': 29.564154, 'longitude': -98.488924}, 'transactions': [], 'price': '$$', 'location': {'address1': '606 Embassy Oaks', 'address2': 'Ste 100', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['606  ...
# 50
# {'businesses': [{'id': 'fjQyLm3ktC8hqRm97cuYMA', 'alias': 'the-dogfather-san-antonio', 'name': 'The Dogfather', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mI5ORxsWpdcebabRjOWICg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-dogfather-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 400, 'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'}], 'rating': 4.5, 'coordinates': {'latitude': 29.49353, 'longitude': -98.49965}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '6211 San Pedro Ave', 'address2': '', 'address3': None, 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['6211 San Pedro Ave', 'San Antonio, TX 78216']}, 'phone': '+12104814272', 'display_phone': '(210) 481-4272', 'distance': 1434.8231023329274}, {'id': 'y0G19V0kCxK3XDE4PuEjKw', 'alias': 'tycoon-flats-san-antonio-2', 'name': 'Tycoon Flats', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ulh4HRZSgEoZSkcuWuaH4w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/tycoon-flats-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 793, 'categories': [{'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'newamerican', 'title': 'American (New)'}], 'rating': 4.0, 'coordinates': {'latitude': 29.45228, 'longitude': -98.48491}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '2926 N Saint Marys St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78212', 'country': 'US', 'state': 'TX', 'display_address': ['2926 N Saint Marys St', 'San Antonio, TX 78212']}, 'phone': '+12103200819', 'display_phone': '(210) 320-0819', 'distance': 5492.3288132338575}, {'id': 'jpkIekRcJwkheofnq4tyvw', 'alias': 'picnikins-patio-cafe-san-antonio', 'name': 'Picnikins Patio Cafe', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4pYegdvuamQNIUCzb38eoA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/picnikins-patio-cafe-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 404, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}], 'rating': 4.5, 'coordinates': {'latitude': 29.51892, 'longitude': -98.50789}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '6901 Blanco Rd', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['6901 Blanco Rd', 'San Antonio, TX 78216']}, 'phone': '+12106160954', 'display_phone': '(210) 616-0954', 'distance': 2758.8237756116373}, {'id': '5hMQ3OSkyf2TIhl4b8SQnA', 'alias': 'papas-burgers-san-antonio', 'name': "Papa's Burgers", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oewiih8hXIi4FpQM-MVWgg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/papas-burgers-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 318, 'categories': [{'alias': 'burgers', 'title': 'Burgers'}], 'rating': 5.0, 'coordinates': {'latitude': 29.42598, 'longitude': -98.57525}, 'transactions': [], 'price': '$$', 'location': {'address1': '709 Enrique M Barrera Pkwy', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78237', 'country': 'US', 'state': 'TX', 'display_address': ['709 Enrique M Barrera Pkwy', 'San Antonio, TX 78237']}, 'phone': '+12103367743', 'display_phone': '(210) 336-7743', 'distance': 9624.198013580626}, {'id': 'lsDWBsG1Fk3H4KC101RKyw', 'alias': 'earth-burger-san-antonio-2', 'name': 'Earth Burger', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C9UPnLX376WZSVw_myIhEg/o.jpg ...
# 100
# {'businesses': [{'id': 'cMGoyT5C4u-g9X-0kT4seg', 'alias': 'sanchos-san-antonio', 'name': 'Sanchos', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aT-MdYVOy078GABzXAm4CA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/sanchos-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 383, 'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'mexican', 'title': 'Mexican'}], 'rating': 4.0, 'coordinates': {'latitude': 29.4394378662109, 'longitude': -98.4993057250977}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '628 Jackson St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78212', 'country': 'US', 'state': 'TX', 'display_address': ['628 Jackson St', 'San Antonio, TX 78212']}, 'phone': '+12103201840', 'display_phone': '(210) 320-1840', 'distance': 6285.820450441356}, {'id': 'FBVjK3Wwa8DXL3ZkwbisXg', 'alias': 'rosella-coffee-san-antonio', 'name': 'Rosella Coffee', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1mTmurgsI7X8doz6ldTk7g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rosella-coffee-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 421, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 29.4359881103497, 'longitude': -98.4804011200274}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '203 E Jones Ave', 'address2': 'Ste 101', 'address3': '', 'city': 'San Antonio', 'zip_code': '78215', 'country': 'US', 'state': 'TX', 'display_address': ['203 E Jones Ave', 'Ste 101', 'San Antonio, TX 78215']}, 'phone': '+12102778574', 'display_phone': '(210) 277-8574', 'distance': 7285.493824491583}, {'id': 'F330aBxp1Yf-09TKDMW69A', 'alias': 'revolucion-coffee-juice-san-antonio-2', 'name': 'Revolucion Coffee + Juice', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O5vyzXt6TJc3Vh3Jk4QC7w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/revolucion-coffee-juice-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 331, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}, {'alias': 'vegan', 'title': 'Vegan'}], 'rating': 4.5, 'coordinates': {'latitude': 29.5060940321813, 'longitude': -98.4672218998378}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '7959 Broadway', 'address2': 'Ste 500', 'address3': '', 'city': 'San Antonio', 'zip_code': '78209', 'country': 'US', 'state': 'TX', 'display_address': ['7959 Broadway', 'Ste 500', 'San Antonio, TX 78209']}, 'phone': '+12107010725', 'display_phone': '(210) 701-0725', 'distance': 4746.62429274586}, {'id': 'mNuVbJStfapk38Vxc4YXWg', 'alias': 'chicago-bagel-and-deli-san-antonio', 'name': 'Chicago Bagel & Deli', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-JPR6CI4kWEoiT0vqLClJQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/chicago-bagel-and-deli-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 222, 'categories': [{'alias': 'bagels', 'title': 'Bagels'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.5, 'coordinates': {'latitude': 29.54048, 'longitude': -98.55161}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '10918 Wurzbach Rd', 'address2': 'Ste 132', 'address3': '', 'city': 'San Antonio', 'zip_code': '78230', 'cou ...
# 150
# {'businesses': [{'id': 'VMCEbHfmUmUb2GBG2sP86A', 'alias': 'dallah-mediterranean-cuisine-san-antonio', 'name': 'Dallah Mediterranean Cuisine', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y4sw3ekvGIYiJ-HlHXQQTw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/dallah-mediterranean-cuisine-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 262, 'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}], 'rating': 4.5, 'coordinates': {'latitude': 29.5165141853222, 'longitude': -98.595323190093}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '5450 Babcock Rd', 'address2': 'Ste 112', 'address3': '', 'city': 'San Antonio', 'zip_code': '78240', 'country': 'US', 'state': 'TX', 'display_address': ['5450 Babcock Rd', 'Ste 112', 'San Antonio, TX 78240']}, 'phone': '+12102339574', 'display_phone': '(210) 233-9574', 'distance': 8206.55443649977}, {'id': 'nWxJ0JFuZi-nAzuB1M7P-Q', 'alias': 'danny-boys-hamburgers-san-antonio', 'name': "Danny Boy's Hamburgers", 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sg0VnFgSpEr7UhLHhVAnzw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/danny-boys-hamburgers-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 118, 'categories': [{'alias': 'burgers', 'title': 'Burgers'}], 'rating': 5.0, 'coordinates': {'latitude': 29.45935, 'longitude': -98.52042}, 'transactions': [], 'price': '$', 'location': {'address1': '1537 W Summit Ave', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78201', 'country': 'US', 'state': 'TX', 'display_address': ['1537 W Summit Ave', 'San Antonio, TX 78201']}, 'phone': '+12107361665', 'display_phone': '(210) 736-1665', 'distance': 3947.320424939193}, {'id': 'cjRAR6EWjQfeeCU3jeXSQQ', 'alias': 'high-street-wine-company-san-antonio', 'name': 'High Street Wine Company', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xv7L4z-ergZytpyne-yINg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/high-street-wine-company-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 123, 'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'}], 'rating': 4.5, 'coordinates': {'latitude': 29.4421626, 'longitude': -98.479757}, 'transactions': [], 'price': '$$', 'location': {'address1': '302 Pearl Pkwy', 'address2': 'Ste 104', 'address3': '', 'city': 'San Antonio', 'zip_code': '78215', 'country': 'US', 'state': 'TX', 'display_address': ['302 Pearl Pkwy', 'Ste 104', 'San Antonio, TX 78215']}, 'phone': '+12109089144', 'display_phone': '(210) 908-9144', 'distance': 6742.1267445077765}, {'id': 'vCXT8MFy4U8pW0ZmgoM9Xg', 'alias': 'tongs-thai-restaurant-san-antonio', 'name': "Tong's Thai Restaurant", 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vlIH8rPR4M4Mgjajl5OofQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/tongs-thai-restaurant-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 537, 'categories': [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'vegan', 'title': 'Vegan'}], 'rating': 4.0, 'coordinates': {'latitude': 29.4867884, 'longitude': -98.448251}, 'transactions': ['restaurant_reservation', 'pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1146 Austin Hwy', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78209', 'country': 'US', 'state': 'TX', 'display_address': ['1146 Austin Hwy', 'San Antonio, TX 78209']}, 'phone': '+12108297345', 'display_phone': '(210) 829-7345', 'distance': 6467.698284752496}, {'id': 'y7eRc-MbBnkkxHhDZjJk7g', 'alias': 'el-bucanero-sa ...
# 200
# {'businesses': [{'id': 'wgZ11NCpKKVFSQookNMuMQ', 'alias': '1000-degrees-neapolitan-pizzeria-san-antonio-3', 'name': '1000 Degrees Neapolitan Pizzeria', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MqvylD6lnX_oTsI1jZWrLw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/1000-degrees-neapolitan-pizzeria-san-antonio-3?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 232, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.5, 'coordinates': {'latitude': 29.5464987664286, 'longitude': -98.5759315213569}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '11224 Huebner Rd', 'address2': 'Ste 206', 'address3': None, 'city': 'San Antonio', 'zip_code': '78230', 'country': 'US', 'state': 'TX', 'display_address': ['11224 Huebner Rd', 'Ste 206', 'San Antonio, TX 78230']}, 'phone': '+12103682053', 'display_phone': '(210) 368-2053', 'distance': 8303.799090213643}, {'id': 'MQXWcFXTle2W8uIC1EQbmw', 'alias': 'mr-a-oks-kitchen-san-antonio-2', 'name': "Mr A Ok's Kitchen", 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1YNVlrv-PTfhISPSL1N03w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mr-a-oks-kitchen-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 142, 'categories': [{'alias': 'southern', 'title': 'Southern'}], 'rating': 4.5, 'coordinates': {'latitude': 29.484612, 'longitude': -98.407039}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '4403 Rittiman Rd', 'address2': None, 'address3': '', 'city': 'San Antonio', 'zip_code': '78218', 'country': 'US', 'state': 'TX', 'display_address': ['4403 Rittiman Rd', 'San Antonio, TX 78218']}, 'phone': '+12106424181', 'display_phone': '(210) 642-4181', 'distance': 10449.067645782054}, {'id': '6ybfykroANh4EZxNv0VnbA', 'alias': 'whats-brewing-san-antonio', 'name': "What's Brewing?", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/taIMbDVtx6a40qnSux9Blw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/whats-brewing-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 80, 'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}, {'alias': 'arcades', 'title': 'Arcades'}], 'rating': 5.0, 'coordinates': {'latitude': 29.54505, 'longitude': -98.49706}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '138 W Rhapsody Dr', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['138 W Rhapsody Dr', 'San Antonio, TX 78216']}, 'phone': '+12103088882', 'display_phone': '(210) 308-8882', 'distance': 5878.665344545134}, {'id': '4uzrG-0rH98-r31elBt03w', 'alias': 'ajuúa-san-antonio-3', 'name': 'Ajuúa!', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DVv2hAz3hT6PXw5f5_cRNg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/aju%C3%BAa-san-antonio-3?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 340, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'tex-mex', 'title': 'Tex-Mex'}], 'rating': 4.0, 'coordinates': {'latitude': 29.5524036169485, 'longitude': -98.5736242725811}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '11703 Huebner Rd', 'address2': None, 'address3': '', 'city': 'San Antonio', 'zip_code': '78230', 'country': 'US', 'state': 'TX', 'display_address': ['11703 Huebner Rd', 'San Antonio, TX 78230']}, 'phone': '+12108770600', 'display_phone': '(210) 877-0600', 'distance': 8624.138006220066}, {'id': 'kaMgGNXcrvKTSB9FMD_rkA', 'alias': 'carnitas-lonja ...
# 250
# {'businesses': [{'id': 'Bdy8EVwGmDYoc5w5sP1qiw', 'alias': 'sandwich-de-paris-san-antonio', 'name': 'Sandwich De Paris', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mNspPbsdzY1w4n6QonQo0w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/sandwich-de-paris-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 153, 'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.5, 'coordinates': {'latitude': 29.50079, 'longitude': -98.57659}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '7220 Louis Pasteur Dr', 'address2': 'Ste 142', 'address3': '', 'city': 'San Antonio', 'zip_code': '78229', 'country': 'US', 'state': 'TX', 'display_address': ['7220 Louis Pasteur Dr', 'Ste 142', 'San Antonio, TX 78229']}, 'phone': '+12106923429', 'display_phone': '(210) 692-3429', 'distance': 6052.46315208478}, {'id': 'wVxNl8IBOR_rcOC2NRCS4g', 'alias': 'braza-brava-pizzeria-napoletana-san-antonio', 'name': 'Braza Brava Pizzeria Napoletana', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jDNRaq5gnlpNNIkuLtl49g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/braza-brava-pizzeria-napoletana-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 198, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}], 'rating': 4.0, 'coordinates': {'latitude': 29.5064, 'longitude': -98.46701}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '7959 Broadway St', 'address2': 'Ste 300', 'address3': '', 'city': 'San Antonio', 'zip_code': '78209', 'country': 'US', 'state': 'TX', 'display_address': ['7959 Broadway St', 'Ste 300', 'San Antonio, TX 78209']}, 'phone': '+12103202100', 'display_phone': '(210) 320-2100', 'distance': 4784.686750527561}, {'id': 'AIaUnJgem8lIxerwQObl2Q', 'alias': 'nelsons-bbq-san-antonio-2', 'name': "Nelson's BBQ", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nRErpOZ6Sq5bOfsugO61rg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/nelsons-bbq-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 68, 'categories': [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'southern', 'title': 'Southern'}], 'rating': 5.0, 'coordinates': {'latitude': 29.58782, 'longitude': -98.6336}, 'transactions': [], 'price': '$', 'location': {'address1': '7327 N Loop 1604 W', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78249', 'country': 'US', 'state': 'TX', 'display_address': ['7327 N Loop 1604 W', 'San Antonio, TX 78249']}, 'phone': '+12104734988', 'display_phone': '(210) 473-4988', 'distance': 15517.125590518359}, {'id': 'jlN1FR1FAroEJV7CqywXAw', 'alias': 'ida-claire-san-antonio', 'name': 'Ida Claire', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W8yAsUFGtgF5ZjnhIsOhsw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/ida-claire-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 162, 'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'southern', 'title': 'Southern'}], 'rating': 4.5, 'coordinates': {'latitude': 29.49758, 'longitude': -98.47905}, 'transactions': [], 'price': '$$', 'location': {'address1': '7300 Jones Maltsberger Rd', 'address2': '', 'address3': None, 'city': 'San Antonio', 'zip_code': '78209', 'country': 'US', 'state': 'TX', 'display_address': ['7300 Jones Maltsberger Rd', 'San Antonio, TX 78209']}, 'phone': '+12106672145', 'display_phone': '(210) 667-2145', 'distance': 3440.454328177353}, {'id': 'AXGia-SMVJyevEF7v3VRVQ', 'alias': 'el-paraiso ...
# 300
# {'businesses': [{'id': 'n4GGozaRnFHJMiOVYhH4bA', 'alias': 'azuca-nuevo-latina-san-antonio-2', 'name': 'Azuca Nuevo Latina', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jzu9C9OBcgdeNq2Tg80pBw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/azuca-nuevo-latina-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 356, 'categories': [{'alias': 'latin', 'title': 'Latin American'}, {'alias': 'musicvenues', 'title': 'Music Venues'}, {'alias': 'caribbean', 'title': 'Caribbean'}], 'rating': 4.0, 'coordinates': {'latitude': 29.41716, 'longitude': -98.48868}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '709 S Alamo St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78205', 'country': 'US', 'state': 'TX', 'display_address': ['709 S Alamo St', 'San Antonio, TX 78205']}, 'phone': '+12102255550', 'display_phone': '(210) 225-5550', 'distance': 8950.918171335756}, {'id': 'MDoOUUUdCOh4SYoWwkvPnw', 'alias': 'w-d-deli-san-antonio', 'name': 'W D Deli', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2vcrNqnzeRaOU5dBwjS0qw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/w-d-deli-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 193, 'categories': [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'desserts', 'title': 'Desserts'}], 'rating': 4.0, 'coordinates': {'latitude': 29.45613, 'longitude': -98.47064}, 'transactions': ['delivery', 'pickup'], 'price': '$', 'location': {'address1': '3123 Broadway St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78209', 'country': 'US', 'state': 'TX', 'display_address': ['3123 Broadway St', 'San Antonio, TX 78209']}, 'phone': '+12108282322', 'display_phone': '(210) 828-2322', 'distance': 6011.31662832637}, {'id': 'uKEZZljjr5YxbF4adUno-A', 'alias': 'the-original-blanco-cafe-san-antonio-2', 'name': 'The Original Blanco Cafe', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/adx0N_qRTzyjjfi0QIKV6g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-original-blanco-cafe-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 278, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}], 'rating': 4.0, 'coordinates': {'latitude': 29.42799, 'longitude': -98.49157}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '419 N St Marys St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78205', 'country': 'US', 'state': 'TX', 'display_address': ['419 N St Marys St', 'San Antonio, TX 78205']}, 'phone': '+12102713300', 'display_phone': '(210) 271-3300', 'distance': 7689.027897845343}, {'id': '-g3XtOdjMrpQETcBNGpfHQ', 'alias': 'florios-pizza-san-antonio', 'name': "Florio's Pizza", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q4fL0hHgmpn0evxPYyj_ow/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/florios-pizza-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 282, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.0, 'coordinates': {'latitude': 29.49984, 'longitude': -98.4674299}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '7701 Broadway St', 'address2': 'Ste 2', 'address3': '', 'city': 'San Antonio', 'zip_code': '78209', 'country': 'US', 'state': 'TX', 'display_address': ['7701 Broadway St', 'Ste 2', 'San Antonio, TX 78209']}, 'phone': '+12108058646', 'display_phone': '(210) 805-8646', 'distance': 4606.19657208228}, {'id': 'Y767McO3pyrNmWx7nxD3xw', 'alias': 'saeb-thai-and-noodles-san-antonio', 'name': 'Saeb T ...
# 350
# {'businesses': [{'id': '5qUivpj_zEU2zfSGL1yr1g', 'alias': 'crepeccino-san-antonio', 'name': 'Crepeccino', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PxLfhGCkmBp_VZB2nb3CcA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/crepeccino-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 131, 'categories': [{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'creperies', 'title': 'Creperies'}, {'alias': 'gelato', 'title': 'Gelato'}], 'rating': 4.5, 'coordinates': {'latitude': 29.5168035209346, 'longitude': -98.597553878541}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '5500 Babcock Rd', 'address2': 'Ste 104', 'address3': None, 'city': 'San Antonio', 'zip_code': '78240', 'country': 'US', 'state': 'TX', 'display_address': ['5500 Babcock Rd', 'Ste 104', 'San Antonio, TX 78240']}, 'phone': '+12106003362', 'display_phone': '(210) 600-3362', 'distance': 8422.22370128478}, {'id': 'thoppZoZ0yzdlz-8RexoFg', 'alias': 'topgolf-san-antonio', 'name': 'Topgolf', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bQPB3pPzje1Yew9t8tsGIQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/topgolf-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 365, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'golf', 'title': 'Golf'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}], 'rating': 3.5, 'coordinates': {'latitude': 29.594147, 'longitude': -98.594985}, 'transactions': [], 'price': '$$', 'location': {'address1': '5539 N Loop 1604 W', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78249', 'country': 'US', 'state': 'TX', 'display_address': ['5539 N Loop 1604 W', 'San Antonio, TX 78249']}, 'phone': '+12102022694', 'display_phone': '(210) 202-2694', 'distance': 13553.12599461676}, {'id': 'hAg77dR1TNzi6E1H_407sQ', 'alias': 'gold-coffee-company-san-antonio', 'name': 'Gold Coffee Company', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X7GrCp11XOfKH0DS8eazTg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/gold-coffee-company-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 43, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 5.0, 'coordinates': {'latitude': 29.40553, 'longitude': -98.50299}, 'transactions': [], 'price': '$$', 'location': {'address1': '1913 S Flores', 'address2': None, 'address3': '', 'city': 'San Antonio', 'zip_code': '78224', 'country': 'US', 'state': 'TX', 'display_address': ['1913 S Flores', 'San Antonio, TX 78224']}, 'phone': '+17602015855', 'display_phone': '(760) 201-5855', 'distance': 9953.423834439698}, {'id': 'dzM1EmZgg0PJKjhN1DxMJQ', 'alias': 'beirut-san-antonio', 'name': 'Beirut', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zJQwUzVkWhOy4WaZtK0KeQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/beirut-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 55, 'categories': [{'alias': 'falafel', 'title': 'Falafel'}, {'alias': 'burgers', 'title': 'Burgers'}, {'alias': 'kebab', 'title': 'Kebab'}], 'rating': 5.0, 'coordinates': {'latitude': 29.5179941, 'longitude': -98.5627351}, 'transactions': ['delivery'], 'location': {'address1': '4085 Medical Dr', 'address2': '', 'address3': None, 'city': 'San Antonio', 'zip_code': '78229', 'country': 'US', 'state': 'TX', 'display_address': ['4085 Medical Dr', 'San Antonio, TX 78229']}, 'phone': '+12107691241', 'display_phone': '(210) 769-1241', 'distance': 5384.996886219432}, {'id': 'YHD8FTI-wZrbgy9pOfFwOA', 'alias': 'aloha-shaved-ice-fruit-cups-and-more-san-antonio', 'name': 'Aloha Shave ...
# 400
# {'businesses': [{'id': 'WWk2ugwbZ3Cq_ADFh8jMcg', 'alias': 'viva-villa-san-antonio', 'name': 'Viva Villa', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ga-wSh2-PemuWff9BBOUQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/viva-villa-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 248, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'tex-mex', 'title': 'Tex-Mex'}], 'rating': 3.5, 'coordinates': {'latitude': 29.42468, 'longitude': -98.49945}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '905 Dolorosa', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78207', 'country': 'US', 'state': 'TX', 'display_address': ['905 Dolorosa', 'San Antonio, TX 78207']}, 'phone': '+12109878482', 'display_phone': '(210) 987-8482', 'distance': 7898.616518021242}, {'id': 'BiNmstOGccF4-8Isfvgpuw', 'alias': 'bombay-bicycle-club-san-antonio', 'name': 'Bombay Bicycle Club', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mosvl0ecNg1zt050TzPSSA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bombay-bicycle-club-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 167, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'burgers', 'title': 'Burgers'}], 'rating': 4.0, 'coordinates': {'latitude': 29.457093, 'longitude': -98.478578}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '3506 N Saint Marys St', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78212', 'country': 'US', 'state': 'TX', 'display_address': ['3506 N Saint Marys St', 'San Antonio, TX 78212']}, 'phone': '+12107372411', 'display_phone': '(210) 737-2411', 'distance': 5410.3221538117905}, {'id': 'FD86_XYF6hUL40h-WutSSQ', 'alias': 'moroccan-cuisine-san-antonio', 'name': 'Moroccan Cuisine', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OhTLCuF8EvlWoDcy6CCmxQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/moroccan-cuisine-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 59, 'categories': [{'alias': 'moroccan', 'title': 'Moroccan'}, {'alias': 'hookah_bars', 'title': 'Hookah Bars'}], 'rating': 4.5, 'coordinates': {'latitude': 29.51189, 'longitude': -98.5694}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '7959 Fredericksburg Rd', 'address2': 'Ste 215', 'address3': '', 'city': 'San Antonio', 'zip_code': '78229', 'country': 'US', 'state': 'TX', 'display_address': ['7959 Fredericksburg Rd', 'Ste 215', 'San Antonio, TX 78229']}, 'phone': '+12105494031', 'display_phone': '(210) 549-4031', 'distance': 5664.996427054132}, {'id': '3hM5fxiV1KOM8iDf0TJfVw', 'alias': 'thai-topaz-san-antonio-21', 'name': 'Thai Topaz', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mtHpwbrL2oS76FS-R7D6_A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/thai-topaz-san-antonio-21?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 231, 'categories': [{'alias': 'thai', 'title': 'Thai'}], 'rating': 4.0, 'coordinates': {'latitude': 29.5323974, 'longitude': -98.5221181}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '2177 NW Military Hwy', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78213', 'country': 'US', 'state': 'TX', 'display_address': ['2177 NW Military Hwy', 'San Antonio, TX 78213']}, 'phone': '+12102909833', 'display_phone': '(210) 290-9833', 'distance': 4298.939365472045}, {'id': 'ui-vgn3xWPAv1T22qRb8Uw', 'alias': 'snowflake-donu ...
# 450
# {'businesses': [{'id': '3peI9cv75ldz3X3FR3rOAQ', 'alias': 'lemongrass-thai-restaurant-san-antonio', 'name': 'Lemongrass Thai Restaurant', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g7ejzb5EMZrbxDbnShyODA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/lemongrass-thai-restaurant-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 163, 'categories': [{'alias': 'thai', 'title': 'Thai'}], 'rating': 4.0, 'coordinates': {'latitude': 29.594312, 'longitude': -98.471724}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '16666 US Hwy 281 N', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78232', 'country': 'US', 'state': 'TX', 'display_address': ['16666 US Hwy 281 N', 'San Antonio, TX 78232']}, 'phone': '+12104903636', 'display_phone': '(210) 490-3636', 'distance': 11848.090108920882}, {'id': '9IvCOANZzgnbEHrPpw5vQQ', 'alias': 'kona-grill-san-antonio', 'name': 'Kona Grill', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HarzRQ4zzz6bhTa05ZbLXQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/kona-grill-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 526, 'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'newamerican', 'title': 'American (New)'}], 'rating': 3.5, 'coordinates': {'latitude': 29.593554, 'longitude': -98.614506}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '15900 La Cantera Pkwy', 'address2': 'Ste 7-7300', 'address3': 'The Shops at La Cantera', 'city': 'San Antonio', 'zip_code': '78256', 'country': 'US', 'state': 'TX', 'display_address': ['15900 La Cantera Pkwy', 'Ste 7-7300', 'The Shops at La Cantera', 'San Antonio, TX 78256']}, 'phone': '+12108775355', 'display_phone': '(210) 877-5355', 'distance': 14670.94160006607}, {'id': 'CwXW9McbuiW86Mx_oad_Cg', 'alias': 'mod-pizza-san-antonio-2', 'name': 'MOD Pizza', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QdBQKfcfsR2ootibotpOsw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mod-pizza-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 143, 'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}, {'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.0, 'coordinates': {'latitude': 29.5637340545654, 'longitude': -98.5877075195312}, 'transactions': [], 'price': '$', 'location': {'address1': '5230 De Zavala Rd', 'address2': 'Ste 234', 'address3': None, 'city': 'San Antonio', 'zip_code': '78249', 'country': 'US', 'state': 'TX', 'display_address': ['5230 De Zavala Rd', 'Ste 234', 'San Antonio, TX 78249']}, 'phone': '+12108192991', 'display_phone': '(210) 819-2991', 'distance': 10483.417164912538}, {'id': 'U9UkzNuNsFguCu3qT_TEIg', 'alias': 'mimis-barbacoa-and-tamales-y-mas-san-antonio', 'name': "Mimi's Barbacoa and Tamales Y Mas", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/94B1LcwVwK27R9tMh-AETA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mimis-barbacoa-and-tamales-y-mas-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 117, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}], 'rating': 4.0, 'coordinates': {'latitude': 29.541007, 'longitude': -98.551544}, 'transactions': [], 'price': '$', 'location': {'address1': '10918 Wurzbach Rd', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78230', 'country': 'US', 'state': 'TX', 'display_address': ['10918 Wurzbach Rd', 'San Antonio, TX 78230']}, 'phone': '+12105586008', 'display_phone': '(210) 558-6008', 'distance': 6303.055 ...
# 500
# {'businesses': [{'id': 'i74EUtWgXFmhYPNnuUttzA', 'alias': 'salata-san-antonio-4', 'name': 'Salata', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k3RWOPE11i9gO4MnB1UVJg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/salata-san-antonio-4?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 67, 'categories': [{'alias': 'salad', 'title': 'Salad'}], 'rating': 4.5, 'coordinates': {'latitude': 29.5200551, 'longitude': -98.5023274}, 'transactions': [], 'price': '$$', 'location': {'address1': '510 NW Loop 410', 'address2': 'Ste 105', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['510 NW Loop 410', 'Ste 105', 'San Antonio, TX 78216']}, 'phone': '+12102814320', 'display_phone': '(210) 281-4320', 'distance': 3081.879648524796}, {'id': 'Oai-sHnu-jqGr3MSU6X6hg', 'alias': 'betty-janes-bakeshoppe-san-antonio', 'name': "Betty Jane's Bakeshoppe", 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nM2MBIpIJ-U-0e-f_no7Qw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/betty-janes-bakeshoppe-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 50, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}], 'rating': 4.5, 'coordinates': {'latitude': 29.573481, 'longitude': -98.515944}, 'transactions': [], 'price': '$$', 'location': {'address1': '14377 Blanco Rd', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['14377 Blanco Rd', 'San Antonio, TX 78216']}, 'phone': '+12104921952', 'display_phone': '(210) 492-1952', 'distance': 8790.398875283674}, {'id': '2L0YZrItpoMrqD-SYXzspw', 'alias': 'briscoe-western-art-museum-san-antonio', 'name': 'Briscoe Western Art Museum', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yl27hynVYNRHhv2UHh7j1Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/briscoe-western-art-museum-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 68, 'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}], 'rating': 4.5, 'coordinates': {'latitude': 29.42303, 'longitude': -98.48909}, 'transactions': [], 'location': {'address1': '210 W Market St', 'address2': None, 'address3': None, 'city': 'San Antonio', 'zip_code': '78205', 'country': 'US', 'state': 'TX', 'display_address': ['210 W Market St', 'San Antonio, TX 78205']}, 'phone': '+12102994499', 'display_phone': '(210) 299-4499', 'distance': 8326.216318710602}, {'id': '6SKg6EMiqG8OsF7_aUFRgw', 'alias': 'jet-setter-san-antonio', 'name': 'Jet-Setter', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3U2EZcw5L5oGuub3AefrxQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/jet-setter-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 56, 'categories': [{'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}], 'rating': 4.5, 'coordinates': {'latitude': 29.42662, 'longitude': -98.49013}, 'transactions': [], 'price': '$$', 'location': {'address1': '229 E Houston St', 'address2': 'Ste 10', 'address3': '', 'city': 'San Antonio', 'zip_code': '78205', 'country': 'US', 'state': 'TX', 'display_address': ['229 E Houston St', 'Ste 10', 'San Antonio, TX 78205']}, 'phone': '+12102720457', 'display_phone': '(210) 272-0457', 'distance': 7896.507845837398}, {'id': 'uJ0Q4GphHWVkJy9SenyLGA', 'alias': 'ritas-on-the-river-san-antonio', 'name': "Rita's on the River", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/35bg3PF6icsJLGs1p4-x0g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/ritas-on-the-river-san-antoni ...
# 550
# ...
# 850
# {'businesses': [{'id': '2piFN_O_Ge5fXJdXXp7LFQ', 'alias': 'back-unturned-brewing-san-antonio', 'name': 'Back Unturned Brewing', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n73KA8zVxe9YjbAx2n1PFw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/back-unturned-brewing-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 23, 'categories': [{'alias': 'brewpubs', 'title': 'Brewpubs'}, {'alias': 'pizza', 'title': 'Pizza'}], 'rating': 5.0, 'coordinates': {'latitude': 29.4330983926469, 'longitude': -98.4845251590014}, 'transactions': [], 'price': '$$', 'location': {'address1': '516 Brooklyn Ave', 'address2': '', 'address3': None, 'city': 'San Antonio', 'zip_code': '78215', 'country': 'US', 'state': 'TX', 'display_address': ['516 Brooklyn Ave', 'San Antonio, TX 78215']}, 'phone': '+12102570022', 'display_phone': '(210) 257-0022', 'distance': 7408.740129248403}, {'id': 'bCMrpRz1j_LDi_DEB1jQOA', 'alias': 'lennys-grill-and-subs-san-antonio-2', 'name': 'Lennys Grill & Subs', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ExatkxBocXk_mKUdgbNpRA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/lennys-grill-and-subs-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 56, 'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.0, 'coordinates': {'latitude': 29.5555016682523, 'longitude': -98.5356269664462}, 'transactions': ['delivery', 'pickup'], 'price': '$', 'location': {'address1': '11503 NW Military Hwy', 'address2': 'Ste 117', 'address3': '', 'city': 'San Antonio', 'zip_code': '78231', 'country': 'US', 'state': 'TX', 'display_address': ['11503 NW Military Hwy', 'Ste 117', 'San Antonio, TX 78231']}, 'phone': '+12104921098', 'display_phone': '(210) 492-1098', 'distance': 7093.630216520016}, {'id': 'Vo57vpv_AwNa-M9CsvgXQQ', 'alias': 'bottling-department-san-antonio', 'name': 'Bottling Department', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rYwSN37IUp7183xz0Vpmow/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bottling-department-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 59, 'categories': [{'alias': 'food_court', 'title': 'Food Court'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 29.442789, 'longitude': -98.480575}, 'transactions': [], 'price': '$$', 'location': {'address1': '312 Pearl Pkwy', 'address2': 'Bldg 6', 'address3': None, 'city': 'San Antonio', 'zip_code': '78215', 'country': 'US', 'state': 'TX', 'display_address': ['312 Pearl Pkwy', 'Bldg 6', 'San Antonio, TX 78215']}, 'phone': '+12105649140', 'display_phone': '(210) 564-9140', 'distance': 6585.490449081063}, {'id': 'Uvtdmlvsby0KjkeG6voS6g', 'alias': 'el-jarro-de-arturo-san-antonio', 'name': 'El Jarro De Arturo', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/D6hRIPulgKgdquV4-o8LKA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/el-jarro-de-arturo-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 241, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}, {'alias': 'tex-mex', 'title': 'Tex-Mex'}, {'alias': 'seafood', 'title': 'Seafood'}], 'rating': 3.0, 'coordinates': {'latitude': 29.5648932434647, 'longitude': -98.4840199876231}, 'transactions': ['delivery'], 'price': '$$', 'location': {'address1': '13421 San Pedro Ave', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['13421 San Pedro Ave', 'San Antonio, TX 78216']}, 'phone': '+12104945084', 'display_phone': '(210) 494-5084', 'distance': 8367.609747495659}, { ...
# 900
# {'businesses': [{'id': 'GSfkUtKp02u06WjLQfTo3Q', 'alias': 'la-gloria-san-antonio-2', 'name': 'La Gloria', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TgexABzJkBPKI8PdiUXF7g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/la-gloria-san-antonio-2?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 310, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}], 'rating': 2.5, 'coordinates': {'latitude': 29.5263351502758, 'longitude': -98.4720464515239}, 'transactions': [], 'price': '$$', 'location': {'address1': '9800 Airport Terminal', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['9800 Airport Terminal', 'San Antonio, TX 78216']}, 'phone': '+12108240637', 'display_phone': '(210) 824-0637', 'distance': 5420.402260400723}, {'id': 'SCYKUDRfSn6Bg1bxp7kMeQ', 'alias': 'jasons-deli-san-antonio', 'name': "Jason's Deli", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vbRFEvzo5UrEYbyufC1IjA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/jasons-deli-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 90, 'categories': [{'alias': 'delis', 'title': 'Delis'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'salad', 'title': 'Salad'}], 'rating': 3.5, 'coordinates': {'latitude': 29.5214136654887, 'longitude': -98.4938001480065}, 'transactions': [], 'price': '$', 'location': {'address1': '25 NE Loop 410', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['25 NE Loop 410', 'San Antonio, TX 78216']}, 'phone': '+12105249288', 'display_phone': '(210) 524-9288', 'distance': 3601.7674818720297}, {'id': 'pev_TzTV0fheEDa3-WZICw', 'alias': 'krispy-kreme-san-antonio-6', 'name': 'Krispy Kreme', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sqvEzIdYtTQZ6wZr2QfRzQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/krispy-kreme-san-antonio-6?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 79, 'categories': [{'alias': 'donuts', 'title': 'Donuts'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 3.5, 'coordinates': {'latitude': 29.558791, 'longitude': -98.590594}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '12238 Interstate Hwy 10 W', 'address2': None, 'address3': None, 'city': 'San Antonio', 'zip_code': '78230', 'country': 'US', 'state': 'TX', 'display_address': ['12238 Interstate Hwy 10 W', 'San Antonio, TX 78230']}, 'phone': '+12106967771', 'display_phone': '(210) 696-7771', 'distance': 10273.494953143716}, {'id': 'ojyfSAA5UR4WuGpR8rEM0w', 'alias': 'attaboy-burgers-san-antonio', 'name': 'Attaboy Burgers', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rN7wpZwZYK3b3lR37XjRqw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/attaboy-burgers-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 56, 'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'burgers', 'title': 'Burgers'}], 'rating': 4.0, 'coordinates': {'latitude': 29.411741, 'longitude': -98.493575}, 'transactions': [], 'price': '$$', 'location': {'address1': "2410 N St Mary's", 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78212', 'country': 'US', 'state': 'TX', 'display_address': ["2410 N St Mary's", 'San Antonio, TX 78212']}, 'phone': '', 'display_phone': '', 'distance': 9414.073962447887}, {'id': 'arAjKa-Vn7jGw9RPKevNsw', 'alias': 'joes-crab-shack-san-antonio-2', 'name': "Joe's Crab Shack", 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/z3CDurxJqG1 ...
# 950
# {'businesses': [{'id': 'yGUN-JntYW_I5EYMtCuMeQ', 'alias': 'havana-bar-san-antonio', 'name': 'Havana Bar', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7UI1kCKveOd6XtX-64u1XQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/havana-bar-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 36, 'categories': [{'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 29.4308109, 'longitude': -98.4897385}, 'transactions': [], 'price': '$$', 'location': {'address1': '1015 Navarro St', 'address2': '', 'address3': 'Hotel Havana', 'city': 'San Antonio', 'zip_code': '78205', 'country': 'US', 'state': 'TX', 'display_address': ['1015 Navarro St', 'Hotel Havana', 'San Antonio, TX 78205']}, 'phone': '+12102222008', 'display_phone': '(210) 222-2008', 'distance': 7461.005034599621}, {'id': 'ZEGTRQfoMA6pvKbknP7UsQ', 'alias': 'vietnam-gardens-san-antonio', 'name': 'Vietnam Gardens', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IyxdOcDn16RofDQZbx043w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/vietnam-gardens-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 46, 'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'thai', 'title': 'Thai'}], 'rating': 4.0, 'coordinates': {'latitude': 29.503003, 'longitude': -98.508162}, 'transactions': ['delivery'], 'price': '$', 'location': {'address1': '5433 Blanco Rd', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78216', 'country': 'US', 'state': 'TX', 'display_address': ['5433 Blanco Rd', 'San Antonio, TX 78216']}, 'phone': '+12103771989', 'display_phone': '(210) 377-1989', 'distance': 1127.8047430610593}, {'id': 'FAUR-UbctOGtVnEcW3S7yg', 'alias': 'little-penguins-snacks-san-antonio', 'name': 'Little Penguins Snacks', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LQWdy_DtGUgVBjyyQf-eEw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/little-penguins-snacks-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 17, 'categories': [{'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'shavedice', 'title': 'Shaved Ice'}], 'rating': 5.0, 'coordinates': {'latitude': 29.4508580394062, 'longitude': -98.5127133232778}, 'transactions': [], 'price': '$$', 'location': {'address1': '820 Fredericksburg Rd', 'address2': '', 'address3': '', 'city': 'San Antonio', 'zip_code': '78201', 'country': 'US', 'state': 'TX', 'display_address': ['820 Fredericksburg Rd', 'San Antonio, TX 78201']}, 'phone': '+12107334249', 'display_phone': '(210) 733-4249', 'distance': 4848.6633650526155}, {'id': 'qsFA0cuvL-uWApSOPIy1DA', 'alias': 'bobalicious-wi-fi-cafe-san-antonio', 'name': 'Bobalicious Wi-fi Cafe', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hmrQVWjMjlGlxj3y-te3LQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bobalicious-wi-fi-cafe-san-antonio?adjust_creative=Lhvl9SWFDeWvFL0GaFLIsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Lhvl9SWFDeWvFL0GaFLIsw', 'review_count': 111, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}], 'rating': 3.5, 'coordinates': {'latitude': 29.49007, 'longitude': -98.5836}, 'transactions': ['delivery', 'pickup'], 'price': '$', 'location': {'address1': '4907 NW Loop 410', 'address2': 'Ste 103', 'address3': '', 'city': 'San Antonio', 'zip_code': '78229', 'country': 'US', 'state': 'TX', 'display_address': ['4907 NW Loop 410', 'Ste 103', 'San Antonio, TX 78229']}, 'phone': '+12109798040', 'display_phone': '(210) 979-8040', 'distance': 6716.865029929097}, {'id': 'N7QpGXAi1oHBYgKwS1sYvA', 'alias': 'the-base-line-san-anto ...

# %%
def search_restaurants2(set_num): 
# This function launches the request for all restaurants in San Antonio, Tx.
cat
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': 'Bearer %s'% api_key,
    }
    
    url_params = { #parameters passed to the API
    "location":"San Antonio",
    "categories": categories
    "state": "Texas",
    'offset': offset_num, # We are going to iterate the offset
     "limit":50 # Maximum return of results per request (ref: API documentation).
     }

    response = requests.get(url, headers=headers, params=url_params)
    return response.json() # Returns a JSON.


if __name__ == "__main__":
    for offset_num in np.arange(1001,2000,50) : 
# Desire 3200 results, in steps of 50 results per request.
        try:
            output_json = search_restaurants(offset_num) # Executing the function defined above.
            print(offset_num) # Making sure each offset iteration is running
            print(output_json) # If you wanna check the JSON for each iteration
            if offset_num == 50:
                df_first = pd.DataFrame.from_dict(output_json['businesses'])
# 'businesses' because that's the primary key of the JSON (i.e. pull all attribute data by calling 
# that one key). This is something you can figure out reading the API documentation or visually
# parsing the JSON. 
            else:
                df_first = pd.DataFrame.from_dict(output_json['businesses'])
                df2 = pd.DataFrame.from_dict(output_json['businesses'])
                df_first = df_first.append(df2)
# The conditional statement above is so that I can append my results into a single dataframe, to 
# save into a single csv document.
        except AttributeError:
            print("error at ", offset_num) # Helpful for debugging purposes
            
    df_first.to_csv("output_data2.csv", index = False)
# Out:
# 1001
# {'error': {'code': 'VALIDATION_ERROR', 'description': '1001 is greater than the maximum of 1000', 'field': 'offset', 'instance': 1001}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-274ca78eb6da> in <module>
#      30 # parsing the JSON.
#      31             else:
# ---> 32                 df_first = pd.DataFrame.from_dict(output_json['businesses'])
#      33                 df2 = pd.DataFrame.from_dict(output_json['businesses'])
#      34                 df_first = df_first.append(df2)
#
# KeyError: 'businesses'

# %%
categories = """
afghani
african
newamerican
tradamerican
andalusian
arabian
argentine
armenian
asianfusion
asturian
australian
austrian
baguettes
bangladeshi
bbq
basque
bavarian
beergarden
beerhall
beisl
belgian
bistros
blacksea
brasseries
brazilian
breakfast_brunch
british
buffets
bulgarian
burgers
burmese
cafes
themedcafes
cafeteria
cajun
cambodian
newcanadian
canteen
caribbean
catalan
cheesesteaks
chickenshop
chicken_wings
chilean
chinese
comfortfood
corsican
creperies
cuban
currysausage
cypriot
czech
czechslovakian
danish
delis
diners
dinnertheater
dumplings
eastern_european
eritrean
ethiopian
hotdogs
filipino
fischbroetchen
fishnchips
flatbread
fondue
food_court
foodstands
freiduria
french
sud_ouest
galician
gamemeat
gastropubs
georgian
german
giblets
gluten_free
greek
guamanian
halal
hawaiian
heuriger
himalayan
honduran
hkcafe
hotdog
hotpot
hungarian
iberian
indpak
indonesian
international
irish
island_pub
israeli
italian
japanese
jewish
kebab
kopitiam
korean
kosher
kurdish
laos
laotian
latin
raw_food
lyonnais
malaysian
meatballs
mediterranean
mexican
mideastern
milkbars
modern_australian
modern_european
mongolian
moroccan
newmexican
newzealand
nicaraguan
nightfood
nikkei
noodles
norcinerie
opensandwiches
oriental
pfcomercial
pakistani
panasian
eltern_cafes
parma
persian
peruvian
pita
pizza
polish
polynesian
popuprestaurants
portuguese
potatoes
poutineries
pubfood
riceshop
romanian
rotisserie_chicken
russian
salad
sandwiches
scandinavian
schnitzel
scottish
seafood
serbocroatian
signature_cuisine
singaporean
slovakian
somali
soulfood
soup
southern
spanish
srilankan
steak
supperclubs
sushi
swabian
swedish
swissfood
syrian
tabernas
taiwanese
tapas
tapasmallplates
tavolacalda
tex-mex
thai
norwegian
traditional_swedish
trattorie
turkish
ukrainian
uzbek
vegan
vegetarian
venison
vietnamese
waffles
wok
wraps
yugoslav
food
hotelstravel
bedbreakfast
foodtours
nightlife
bars
religiousorgs
"""

# %%
categories = categories.split()

# %%
categories
# Out:
# ['afghani',
#  'african',
#  'newamerican',
#  'tradamerican',
#  'andalusian',
#  'arabian',
#  'argentine',
#  'armenian',
#  'asianfusion',
#  'asturian',
#  'australian',
#  'austrian',
#  'baguettes',
#  'bangladeshi',
#  'bbq',
#  'basque',
#  'bavarian',
#  'beergarden',
#  'beerhall',
#  'beisl',
#  'belgian',
#  'bistros',
#  'blacksea',
#  'brasseries',
#  'brazilian',
#  'breakfast_brunch',
#  'british',
#  'buffets',
#  'bulgarian',
#  'burgers',
#  'burmese',
#  'cafes',
#  'themedcafes',
#  'cafeteria',
#  'cajun',
#  'cambodian',
#  'newcanadian',
#  'canteen',
#  'caribbean',
#  'catalan',
#  'cheesesteaks',
#  'chickenshop',
#  'chicken_wings',
#  'chilean',
#  'chinese',
#  'comfortfood',
#  'corsican',
#  'creperies',
#  'cuban',
#  'currysausage',
#  'cypriot',
#  'czech',
#  'czechslovakian',
#  'danish',
#  'delis',
#  'diners',
#  'dinnertheater',
#  'dumplings',
#  'eastern_european',
#  'eritrean',
#  'ethiopian',
#  'hotdogs',
#  'filipino',
#  'fischbroetchen',
#  'fishnchips',
#  'flatbread',
#  'fondue',
#  'food_court',
#  'foodstands',
#  'freiduria',
#  'french',
#  'sud_ouest',
#  'galician',
#  'gamemeat',
#  'gastropubs',
#  'georgian',
#  'german',
#  'giblets',
#  'gluten_free',
#  'greek',
#  'guamanian',
#  'halal',
#  'hawaiian',
#  'heuriger',
#  'himalayan',
#  'honduran',
#  'hkcafe',
#  'hotdog',
#  'hotpot',
#  'hungarian',
#  'iberian',
#  'indpak',
#  'indonesian',
#  'international',
#  'irish',
#  'island_pub',
#  'israeli',
#  'italian',
#  'japanese',
#  'jewish',
#  'kebab',
#  'kopitiam',
#  'korean',
#  'kosher',
#  'kurdish',
#  'laos',
#  'laotian',
#  'latin',
#  'raw_food',
#  'lyonnais',
#  'malaysian',
#  'meatballs',
#  'mediterranean',
#  'mexican',
#  'mideastern',
#  'milkbars',
#  'modern_australian',
#  'modern_european',
#  'mongolian',
#  'moroccan',
#  'newmexican',
#  'newzealand',
#  'nicaraguan',
#  'nightfood',
#  'nikkei',
#  'noodles',
#  'norcinerie',
#  'opensandwiches',
#  'oriental',
#  'pfcomercial',
#  'pakistani',
#  'panasian',
#  'eltern_cafes',
#  'parma',
#  'persian',
#  'peruvian',
#  'pita',
#  'pizza',
#  'polish',
#  'polynesian',
#  'popuprestaurants',
#  'portuguese',
#  'potatoes',
#  'poutineries',
#  'pubfood',
#  'riceshop',
#  'romanian',
#  'rotisserie_chicken',
#  'russian',
#  'salad',
#  'sandwiches',
#  'scandinavian',
#  'schnitzel',
#  'scottish',
#  'seafood',
#  'serbocroatian',
#  'signature_cuisine',
#  'singaporean',
#  'slovakian',
#  'somali',
#  'soulfood',
#  'soup',
#  'southern',
#  'spanish',
#  'srilankan',
#  'steak',
#  'supperclubs',
#  'sushi',
#  'swabian',
#  'swedish',
#  'swissfood',
#  'syrian',
#  'tabernas',
#  'taiwanese',
#  'tapas',
#  'tapasmallplates',
#  'tavolacalda',
#  'tex-mex',
#  'thai',
#  'norwegian',
#  'traditional_swedish',
#  'trattorie',
#  'turkish',
#  'ukrainian',
#  'uzbek',
#  'vegan',
#  'vegetarian',
#  'venison',
#  'vietnamese',
#  'waffles',
#  'wok',
#  'wraps',
#  'yugoslav',
#  'food',
#  'hotelstravel',
#  'bedbreakfast',
#  'foodtours',
#  'nightlife',
#  'bars',
#  'religiousorgs']

# %%
def search_restaurants2(set_num): 
# This function launches the request for all restaurants in San Antonio, Tx.
cat
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': 'Bearer %s'% api_key,
    }
    
    url_params = { #parameters passed to the API
    "location":"San Antonio",
    "categories": categories
    "state": "Texas",
    'offset': offset_num, # We are going to iterate the offset
     "limit":50 # Maximum return of results per request (ref: API documentation).
     }

    response = requests.get(url, headers=headers, params=url_params)
    return response.json() # Returns a JSON.


if __name__ == "__main__":
    for offset_num in np.arange(1001,2000,50) : 
# Desire 3200 results, in steps of 50 results per request.
        try:
            output_json = search_restaurants(offset_num) # Executing the function defined above.
            print(offset_num) # Making sure each offset iteration is running
            print(output_json) # If you wanna check the JSON for each iteration
            if offset_num == 50:
                df_first = pd.DataFrame.from_dict(output_json['businesses'])
# 'businesses' because that's the primary key of the JSON (i.e. pull all attribute data by calling 
# that one key). This is something you can figure out reading the API documentation or visually
# parsing the JSON. 
            else:
                df_first = pd.DataFrame.from_dict(output_json['businesses'])
                df2 = pd.DataFrame.from_dict(output_json['businesses'])
                df_first = df_first.append(df2)
# The conditional statement above is so that I can append my results into a single dataframe, to 
# save into a single csv document.
        except AttributeError:
            print("error at ", offset_num) # Helpful for debugging purposes
            
    df_first.to_csv("output_data2.csv", index = False)
